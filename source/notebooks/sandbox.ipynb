# %%
# %cd /code
# Out:
# /code

# %%
from llama_cpp import Llama
from source.library.llm import completion
import source.config.config as config

# %%
model = Llama(model_path=config.LLM_VICUNA_13B, embedding=True)
# Out:
# llama.cpp: loading model from /llms/models/ggml-vic13b-q5_1.bin
# llama_model_load_internal: format     = ggjt v2 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 512
# llama_model_load_internal: n_embd     = 5120
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 40
# llama_model_load_internal: n_layer    = 40
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: ftype      = 9 (mostly Q5_1)
# llama_model_load_internal: n_ff       = 13824
# llama_model_load_internal: n_parts    = 1
# llama_model_load_internal: model size = 13B
# llama_model_load_internal: ggml ctx size =  90.75 KB
# llama_model_load_internal: mem required  = 11359.05 MB (+ 1608.00 MB per state)
# llama_init_from_file: kv self size  =  400.00 MB
# ...

# %%
response = completion(
    model=model,
    prompt="What is the capital of the United States?",
)
response.choices[0].text
# Out:
# llama_print_timings:        load time =  3735.65 ms
# llama_print_timings:      sample time =     6.99 ms /    11 runs   (    0.64 ms per token)
# llama_print_timings: prompt eval time =  3735.61 ms /    10 tokens (  373.56 ms per token)
# llama_print_timings:        eval time =  5410.08 ms /    10 runs   (  541.01 ms per token)
# llama_print_timings:       total time = 10644.39 ms
# '\n\nA: Washington, D.C.'

# %%
model.create_embedding(
    input="What is the compaital of the United States"
)
# Out:
# llama_print_timings:        load time =  3735.65 ms
# llama_print_timings:      sample time =     0.00 ms /     1 runs   (    0.00 ms per token)
# llama_print_timings: prompt eval time =  4107.86 ms /    11 tokens (  373.44 ms per token)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token)
# llama_print_timings:       total time =  4113.81 ms
# {'object': 'list',
#  'data': [{'object': 'embedding',
#    'embedding': [-0.45403656363487244,
#     -0.5020999908447266,
#     -1.2718507051467896,
#     -1.1432108879089355,
#     0.8103896975517273,
#     -0.19431015849113464,
#     -0.8949378728866577,
#     1.3876675367355347,
#     2.258002281188965,
#     1.0536272525787354,
#     0.14949209988117218,
#     -0.018333040177822113,
#     0.9076181054115295,
#     -2.17216157913208,
#     0.6748499870300293,
#     0.7265123128890991,
#     -0.9465652108192444,
#     -0.15011431276798248,
#     3.2975244522094727,
#     1.7966166734695435,
# ...
